# %%
from fastai2.basics           import *
from fastai2.medical.imaging  import *

# %%
train=Path("/home/tkrsh/osic-main/")

# %%
files=[]
for dirname, _, filenames in os.walk(train):
    for filename in (filenames):
        files.append(os.path.join((dirname), filename))        
files=[x for x in files if '.csv' not in x]
train_images= [Path(x) for x in files if 'train'  in x]
test_images = [Path(x) for x in files if 'test'   in x]

# %%
train_images
# Out:
# [Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/64.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/501.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/195.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/278.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/453.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/133.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/346.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/520.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/311.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/222.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/234.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/342.dcm'),
#  Path('/home/tkrsh/osic-main/train/ID00035637202182204917484/395.dcm'),
# ...

# %%
dcm_metadata_train=pd.DataFrame.from_dicoms(trai)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1092' class='' max='33026' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       3.31% [1092/33026 00:06<03:16]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-ec7005c59d81> in <module>
# ----> 1 dcm_metadata_train=pd.DataFrame.from_dicoms(train_images,px_summ=True)
#
# ...

# %%
df=pd.read_csv(main_dir/"train.csv")

# %%
dcm_metadata_test=pd.DataFrame.from_dicoms(test_images,px_summ=True)

# %%
train_images
# Out:
# [Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_4912369.dcm'),
#  Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_5309101.dcm'),
#  Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_4532667.dcm'),
#  Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_1284496.dcm'),
#  Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_1551323.dcm'),
#  Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_5359127.dcm'),
#  Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_5324760.dcm'),
#  Path('/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/train/ISIC_7035246.dcm'),
# ...

# %%
files
# Out:
# ['/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_4313524.dcm',
#  '/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_4814785.dcm',
#  '/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_8544337.dcm',
#  '/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_1443435.dcm',
#  '/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_2010437.dcm',
#  '/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_1339609.dcm',
#  '/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_3174720.dcm',
#  '/media/tkrsh/ebbc93a5-618a-433c-b301-2406c8ffeca7/siim-isic-melanoma-classification/test/ISIC_8941788.dcm',
# ...
